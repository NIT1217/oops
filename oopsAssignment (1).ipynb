# %% [markdown]
# 1.  What is Object-Oriented Programming (OOP)?
# - oops refers to the  part of programing related with the instance , attribute and class ,where the class is the blueprint of the object.

# %% [markdown]
# 2. What is a class in OOP?
# -in object oriented programming the class the blueprint of its object which conrains all the info about the object to be created.

# %% [markdown]
#  3. What is an object in OOP?
#  - An object in Object-Oriented Programming (OOP) is an instance of a class. It is a real-world entity that has:
#
#   State (Attributes/Properties)
#   Behavior (Methods/Functions)

# %% [markdown]
# 4.  What is the difference between abstraction and encapsulation?
#
# - abstraction = it refers to creating a class or a method called abstract clas  and abstract method respectively  , the abstract method dont incude any block of code while initialised , it include block of code in its inherited method
#
# - encapsulation = encapsulation refers to diffrent access modifier
#  1. public modifier = it refers to modifiers which can be accessed in any other subclass or instance directly;
#
#  2 private_modifier = they are modifier which cant be used outside if a class and to use it outside of a class we need to use getter and setter method
#       i.g
#            class bankacount :
#               def __init__(self, balance):
#                   self.__b1 = balance
#
#             def set_balance (self, balance)
#                self.__b1=balance
#
#              def get_balance (self):
#              return self.__b1
#
#
#             obj1 = bankaccount(20000)
#             obj1.set_balance(30000)
#             obj1.get_balnce()
#
#     3. protected modifiers = they are those modifiers which are protected and can be  generated by (_).

# %% [markdown]
# 5. what is dunder method in oops?
# - there are also called magic method or special method and these are the methods surrounded by the double underscore (__). eg. __init__,__call__

# %% [markdown]
# 6. Explain the concept of inheritance in OOP ?
#
#   inheritance refers to the heritance of the parent class to sub class , where the subclass has all the features of parentclass

# %% [markdown]
# 7. What is polymorphism in OOP ?
#
# - polymerphism refers to the many forms it includes the overriding , overloading

# %% [markdown]
# 8. How is encapsulation achieved in Python?
# encapsulation is achieved by usng private attributes and using getter nad setter method

# %% [markdown]
# 9.What is a constructor in Python?
# - constructors refers to the init method in python, it is used to initialised the attribute for the object

# %% [markdown]
# 10. What are class and static methods in Python?
# --class method = these are method which are connected with a particular
#   class and to instanciate it we dont need to create a object and it is done by using @classmethod(decorator) and cls as first parameter
#
# -- static methods = they are those methods which dont need any parameter like cls or self , they are denoted by @staticmethod

# %% [markdown]
# 11. What is method overloading in Python ?
#  - overloading happens in same class and it refers of methods have same name and diffrent parameters

# %% [markdown]
# 12. What is method overriding in OOP?
# - overriding refers to the process in polymerphism in which methods having same name and same parameters but are available in diffrent class
# the  subclass is more powerful than the parent class

# %% [markdown]
# 13. What is a property decorator in Python ?
#  - by using the property decorator over any method we can use it directly without the paranthesis.

# %% [markdown]
# 14. Why is polymorphism important in OOP ?
#  - polymerphism gives us a way to  overcome the problem of oerriding and overloading in oops

# %% [markdown]
# 15. What is an abstract class in Python ?
#  - abstract class is imported from the ABC module and they are those classes which cannt be instanciated directly
#    e.g = from abc import ABC , abstractmethod

# %% [markdown]
# 16. What are the advantages of OOP?
#
#  - oops gives a way for run a code in more arranged order and reusabilt and saves our time.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable ?
# -  class variable are allowed to be used everywhwere in a particular code  using the class_name attribute
#  - instance variable are those variable which are genetared  inthe instance method  and can be used using self attributes

# %% [markdown]
# 18. What is multiple inheritance in Python
# - multiple inheeritance refers to the inheritance of many parents classes in a particular subclass

# %% [markdown]
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?
#
#  - since both are  surrounder by the double underscore so both are dunder methods and their functions are as follow
#
#   a. __str__ = this will represent a string representing a method and is more user friendly
#
#   b.__repr__ = it is used for formal pupose  for a string representing a method

# %% [markdown]
# 20. What is the significance of the ‘super()’ function in Python ?
#
# - super methods are used to make a class as super class and than that class can be called using super().state/behaviour

# %% [markdown]
# 21. What is the significance of the __del__ method in Python?
# - as it is surrounded by the double underscores so it is a dunder method and  stands for the deconstructor .
#
# use = it is used to explicitly delet the instance of a class

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
# - both are decorators and one is used for static method and other is used of class method , both the methods can be called directly without creating any object

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance ?
# - Polymorphism in Python with inheritance allows you to treat objects of different classes in a uniform way. This is achieved through method overriding. Here's how it works:

# %% [markdown]
# 24. What is method chaining in Python OOP ?
# - Method chaining is a technique in object-oriented programming where you can call multiple methods on an object in a single statement. This is achieved by having each method return the object itself (self).

# %% [markdown]
# 25. H What is the purpose of the __call__ method in Python?
#
#  - it is dunder method and use to  convert an object to a class.

# %%
 # 1.Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".

class animal:
   def __init__(self):
    pass

   def speak(self):
    return f"diffrent types of animal have diffrent sounds"

class dog(animal):
  def __init__(self):
    pass

  def speak (self):
    return "bark"


ob1 = dog()
ob1.speak()
# Out:
# 'bark'

# %%
#2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

from abc import ABC , abstractmethod

class shape:
   def __init__(self):
    pass

   def area(self):
    return "the are of the shape depend on the dimensions of the object"

class rectangle(shape):
  def __init__(self):
    pass

  def area(self,length,breadth):
    self.l1 = length
    self.b1 = breadth
    return f"area of the rectangle is {self.l1*self.b1}"

class circle(shape):
   def __init__(self):
    pass

   def area(self,radius):
    self.r1 = radius
    return f"area of the circle is {3.14*(self.r1)**2}"


obj1 = rectangle()
obj1.area(23,56)
obj2 = circle()
obj2.area(34)
ob3 = shape()
ob3.area()
# Out:
# 'the are of the shape depend on the dimensions of the object'

# %%
#3.  3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute



class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type


class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand


class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery = battery_capacity
    def display_info(self):
        print(f"Type: {self.type}, Brand: {self.brand}, Battery: {self.battery} kWh")


tesla = ElectricCar("Four-wheeler", "Tesla", 75)

tesla.display_info()
# Out:
# Type: Four-wheeler, Brand: Tesla, Battery: 75 kWh

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
#Sparrow and Penguin that override the fly() method.

class bird:
  def __init__(self,fly):
    self.f1 = fly

  def fly(self):

    return "every bird fly with its own speed"

class sparrow(bird):
   def __init__(self,fly,colour):
    super().__init__(fly)
    self.c1 = colour
   @property
   def fly(self):
     return f"the color of bird is{self.c1} and the fly with thse speed {self.f1} "

class peigon(bird):
  def __init__(self,fly,colour):
    super().__init__(fly)
    self.c1 = colour
  @property
  def fly(self):
     return f"the color of bird is{self.c1} and the fly with thse speed {self.f1} "



ob1 = sparrow(3000,"white")
ob1.fly
ob1 = peigon(3000,"white and black")
ob1.fly
# Out:
# 'the color of bird iswhite and black and the fly with thse speed 3000 '

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient funds or invalid amount.")

    def get_balance(self):
        return self.__balance

account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)
print("Current Balance:", account.get_balance())
# Out:
# Deposited: 500
# Withdrawn: 300
# Current Balance: 1200

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
#and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Playing an instrument")

class Guitar(Instrument):
    def play(self):
        print("Strumming the Guitar")

class Piano(Instrument):
    def play(self):
        print("Playing the Piano")


instruments = [Guitar(), Piano()]
for instrument in instruments:
    instrument.play()
# Out:
# Strumming the Guitar
# Playing the Piano

# %%
# Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers.
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %%
#. Implement a class Person with a class method to count the total number of persons created.
class Person:
    count = 0  # Class variable to track instances

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# Example usage
p1 = Person("Alice")
p2 = Person("Bob")
print("Total Persons:", Person.total_persons())
# Out:
# Total Persons: 2

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage
fraction = Fraction(3, 4)
print(fraction)
# Out:
# 3/4

# %%
#10 Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

# Example usage
v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2
print(v3)
# Out:
# Vector(6, 8)

# %%
#11 Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


person1 = Person("Alice", 25)
person1.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.

# %%
#12 Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades) if self.grades else 0


student1 = Student("Bob", [85, 90, 78, 92])
print(f"{student1.name}'s Average Grade:", student1.average_grade())
# Out:
# Bob's Average Grade: 86.25

# %%
#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
#area.
class Rectangle:
    def __init__(self):
        self.width = 0
        self.height = 0

    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height


rect = Rectangle()
rect.set_dimensions(5, 10)
print("Rectangle Area:", rect.area())
# Out:
# Rectangle Area: 50

# %%
#14 Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus


emp = Employee("John", 40, 20)
mgr = Manager("Sarah", 40, 30, 500)

print(f"{emp.name}'s Salary:", emp.calculate_salary())
print(f"{mgr.name}'s Salary:", mgr.calculate_salary())
# Out:
# John's Salary: 800
# Sarah's Salary: 1700

# %%
#15. . Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


product = Product("Laptop", 1000, 3)
print(f"Total price of {product.name}: ${product.total_price()}")
# Out:
# Total price of Laptop: $3000

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"


cow = Cow()
sheep = Sheep()

print("Cow:", cow.sound())
print("Sheep:", sheep.sound())
# Out:
# Cow: Moo
# Sheep: Baa

# %%
 #17.Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


book = Book("1984", "George Orwell", 1949)
print(book.get_book_info())
# Out:
# '1984' by George Orwell, published in 1949

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

mansion = Mansion("123 Luxury St", 2000000, 10)
print(f"Mansion at {mansion.address} costs ${mansion.price} with {mansion.number_of_rooms} rooms.")
# Out:
# Mansion at 123 Luxury St costs $2000000 with 10 rooms.
